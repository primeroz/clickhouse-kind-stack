# %%
import pandas as pd
from sklearn_evaluation import plot

# Import jupysql Jupyter extension to create SQL cells
# %load_ext sql
# %config SqlMagic.autocommit=False
# %config SqlMagic.displaylimit=100
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %%
# %sql clickhouse+native://default:@clickhouse.clickhouse:9000

# %%
# %sql describe table btc.blockchain_btc_transactions
# Out:
# Running query in 'clickhouse+native://default:***@clickhouse.clickhouse:9000'
# +-------------------------------+--------------------------------+--------------+--------------------+---------+------------------+----------------+
# |              name             |              type              | default_type | default_expression | comment | codec_expression | ttl_expression |
# +-------------------------------+--------------------------------+--------------+--------------------+---------+------------------+----------------+
# |              hash             |             String             |              |                    |         |                  |                |
# |            version            |        Nullable(Int64)         |              |                    |         |                  |                |
# |              size             |        Nullable(Int64)         |              |                    |         |                  |                |
# ...

# %%
# %%sql
# SELECT
#     hash,
#     version,
#     size,
#     block_hash,
#     block_number,
#     index,
#     virtual_size,
#     lock_time,
#     input_count,
#     output_count,
#     is_coinbase,
#     output_value,
#     block_timestamp,
#     date,
#     last_modified,
#     fee,
#     input_value,
#     inputs
# FROM s3('https://aws-public-blockchain.s3.us-east-2.amazonaws.com/v1.0/btc/transactions/date=2023-08-10/802480.snappy.parquet')
# WHERE hash = '7a8861acc3be70b0d161d9e20b7780cb8ff61a464d67989fa7e0a315e05a7193'
# FORMAT Vertical
# Out:
# Running query in 'clickhouse+native://default:***@clickhouse.clickhouse:9000'
# ...

# %%
# %%sql
# INSERT INTO btc.blockchain_btc_transactions
# SELECT
#     hash,
#     version,
#     size,
#     block_hash,
#     block_number,
#     index,
#     virtual_size,
#     lock_time,
#     input_count,
#     output_count,
#     is_coinbase,
#     output_value,
#     block_timestamp,
#     date,
#     last_modified,
#     fee,
#     input_value,
#     [] as inputs,
#     [] as outputs
# FROM s3('https://aws-public-blockchain.s3.us-east-2.amazonaws.com/v1.0/btc/transactions/date=2023-08-10/802480.snappy.parquet')
# WHERE hash = '7a8861acc3be70b0d161d9e20b7780cb8ff61a464d67989fa7e0a315e05a7193'
# FORMAT Vertical
